# %%
import numpy as np
import pandas as pd
import matplotlib as plt

common_player_info = pd.read_csv(r'C:\Users\matis\OneDrive\Documentos\NBA dataset\csv\common_player_info.csv')
draft_combine_stats = pd.read_csv(r'C:\Users\matis\OneDrive\Documentos\NBA dataset\csv\draft_combine_stats.csv')
draft_history = pd.read_csv(r'C:\Users\matis\OneDrive\Documentos\NBA dataset\csv\draft_history.csv')
game = pd.read_csv(r'C:\Users\matis\OneDrive\Documentos\NBA dataset\csv\game.csv')
game_info = pd.read_csv(r'C:\Users\matis\OneDrive\Documentos\NBA dataset\csv\game_info.csv')
game_summary = pd.read_csv(r'C:\Users\matis\OneDrive\Documentos\NBA dataset\csv\game_summary.csv')
inactive_players = pd.read_csv(r'C:\Users\matis\OneDrive\Documentos\NBA dataset\csv\inactive_players.csv')
line_score = pd.read_csv(r'C:\Users\matis\OneDrive\Documentos\NBA dataset\csv\line_score.csv')
officials = pd.read_csv(r'C:\Users\matis\OneDrive\Documentos\NBA dataset\csv\officials.csv')
other_stats = pd.read_csv(r'C:\Users\matis\OneDrive\Documentos\NBA dataset\csv\other_stats.csv')
player = pd.read_csv(r'C:\Users\matis\OneDrive\Documentos\NBA dataset\csv\player.csv')
play_by_play = pd.read_csv(r'C:\Users\matis\OneDrive\Documentos\NBA dataset\csv\play_by_play.csv')
team = pd.read_csv(r'C:\Users\matis\OneDrive\Documentos\NBA dataset\csv\team.csv')
team_details = pd.read_csv(r'C:\Users\matis\OneDrive\Documentos\NBA dataset\csv\team_details.csv')
team_history = pd.read_csv(r'C:\Users\matis\OneDrive\Documentos\NBA dataset\csv\team_history.csv')
team_info_common = pd.read_csv(r'C:\Users\matis\OneDrive\Documentos\NBA dataset\csv\team_info_common.csv')

# %%
pd.options.display.max_columns = None
common_player_info.head(5)
# Out:
#    person_id first_name     last_name   display_first_last  \
# 0      76001       Alaa     Abdelnaby       Alaa Abdelnaby
# 1      76003     Kareem  Abdul-Jabbar  Kareem Abdul-Jabbar
# 2       1505      Tariq   Abdul-Wahad    Tariq Abdul-Wahad
# 3        949    Shareef   Abdur-Rahim  Shareef Abdur-Rahim
# 4      76005        Tom     Abernethy        Tom Abernethy
#
#   display_last_comma_first  display_fi_last          player_slug  \
# 0          Abdelnaby, Alaa     A. Abdelnaby       alaa-abdelnaby
# 1     Abdul-Jabbar, Kareem  K. Abdul-Jabbar  kareem-abdul-jabbar
# 2       Abdul-Wahad, Tariq   T. Abdul-Wahad    tariq-abdul-wahad
# 3     Abdur-Rahim, Shareef   S. Abdur-Rahim  shareef-abdur-rahim
# 4           Abernethy, Tom     T. Abernethy        tom-abernethy
#
#              birthdate          school country       last_affiliation height  \
# 0  1968-06-24 00:00:00            Duke     USA               Duke/USA   6-10
# ...

# %%
common_player_info = common_player_info[common_player_info['from_year']>=2013]
common_player_info.shape
# Out:
# (839, 33)

# %%
common_player_info.isnull().sum()
# Out:
# person_id                             0
# first_name                            0
# last_name                             0
# display_first_last                    0
# display_last_comma_first              0
# display_fi_last                       0
# player_slug                           0
# birthdate                             0
# school                               12
# country                               0
# last_affiliation                      0
# height                                6
# weight                                6
# season_exp                            0
# jersey                              222
# position                              6
# rosterstatus                          0
# games_played_current_season_flag      0
# team_id                               0
# team_name                           221
# team_abbreviation                   221
# team_code                           221
# team_city                           221
# ...

# %%
pd.options.display.max_columns = None
draft_combine_stats.head(5)
# Out:
#    season  player_id first_name   last_name        player_name position  \
# 0    2001      12033       Adam  Allenspach    Adam Allenspach        C
# 1    2001       2240    Gilbert      Arenas     Gilbert Arenas       SG
# 2    2001       2220    Brandon   Armstrong  Brandon Armstrong       SG
# 3    2001       2203      Shane     Battier      Shane Battier    SF-PF
# 4    2001      12034     Cookie     Belcher     Cookie Belcher    SG-PG
#
#    height_wo_shoes height_wo_shoes_ft_in  height_w_shoes height_w_shoes_ft_in  \
# 0            83.50             6' 11.5''             NaN                  NaN
# 1            74.25             6' 2.25''             NaN                  NaN
# 2            75.50              6' 3.5''             NaN                  NaN
# 3            80.25             6' 8.25''             NaN                  NaN
# 4            75.00                6' 3''             NaN                  NaN
#
# ...

# %%
draft_combine_stats.shape
# Out:
# (1202, 47)

# %%
draft_combine_stats.shape
draft_combine_stats.isnull().sum()
# Out:
# season                             0
# player_id                          0
# first_name                         0
# last_name                          0
# player_name                        0
# position                           5
# height_wo_shoes                   49
# height_wo_shoes_ft_in             49
# height_w_shoes                   194
# height_w_shoes_ft_in             194
# weight                            50
# wingspan                          49
# wingspan_ft_in                    49
# standing_reach                    50
# standing_reach_ft_in              50
# body_fat_pct                     199
# hand_length                      483
# hand_width                       483
# standing_vertical_leap           185
# max_vertical_leap                185
# lane_agility_time                194
# modified_lane_agility_time       791
# three_quarter_sprint             190
# bench_press                      394
# spot_fifteen_corner_left        1128
# ...

# %%
pd.options.display.max_columns = None
draft_history.head(5)
# Out:
#    person_id       player_name  season  round_number  round_pick  \
# 0      79299  Clifton McNeeley    1947             1           1
# 1      78109        Glen Selbo    1947             1           2
# 2      76649      Eddie Ehlers    1947             1           3
# 3      79302        Walt Dropo    1947             1           4
# 4      77048        Dick Holub    1947             1           5
#
#    overall_pick draft_type     team_id   team_city     team_name  \
# 0             1      Draft  1610610031  Pittsburgh       Ironmen
# 1             2      Draft  1610610035     Toronto       Huskies
# 2             3      Draft  1610612738      Boston       Celtics
# 3             4      Draft  1610610032  Providence  Steamrollers
# 4             5      Draft  1610612752    New York        Knicks
#
#   team_abbreviation          organization   organization_type  \
# 0               PIT         Texas-El Paso  College/University
# ...

# %%
draft_history = draft_history[draft_history['season']>=2013]
draft_history.shape
draft_history.isnull().sum()
# Out:
# person_id              0
# player_name            0
# season                 0
# round_number           0
# round_pick             0
# overall_pick           0
# draft_type             0
# team_id                0
# team_city              0
# team_name              0
# team_abbreviation      0
# organization           2
# organization_type      2
# player_profile_flag    0
# dtype: int64

# %%
pd.options.display.max_columns = None
game
# Out:
#        season_id  team_id_home team_abbreviation_home        team_name_home  \
# 52071      42012    1610612743                    DEN        Denver Nuggets
# 52072      42012    1610612751                    BKN         Brooklyn Nets
# 52073      42012    1610612752                    NYK       New York Knicks
# 52074      42012    1610612746                    LAC  Los Angeles Clippers
# 52075      42012    1610612754                    IND        Indiana Pacers
# ...          ...           ...                    ...                   ...
# 65693      42022    1610612748                    MIA            Miami Heat
# 65694      42022    1610612748                    MIA            Miami Heat
# 65695      42022    1610612743                    DEN        Denver Nuggets
# 65696      32022    1610616834                    LBN           Team LeBron
# 65697      32022    1610616834                    LBN           Team LeBron
#
# ...

# %%
game['game_date'] = pd.to_datetime(game['game_date'])
game = game[game['game_date'] >= '01-01-2013']
game.isnull().sum()
# Out:
# season_id                 0
# team_id_home              0
# team_abbreviation_home    0
# team_name_home            0
# game_id                   0
# game_date                 0
# matchup_home              0
# wl_home                   0
# min                       0
# fgm_home                  0
# fga_home                  0
# fg_pct_home               0
# fg3m_home                 0
# fg3a_home                 0
# fg3_pct_home              0
# ftm_home                  0
# fta_home                  0
# ft_pct_home               2
# oreb_home                 0
# dreb_home                 0
# reb_home                  0
# ast_home                  0
# stl_home                  0
# blk_home                  0
# tov_home                  0
# pf_home                   0
# pts_home                  0
# plus_minus_home           0
# video_available_home      0
# team_id_away              0
# team_abbreviation_away    0
# team_name_away            0
# matchup_away              0
# ...

# %%
game.shape
# Out:
# (13627, 55)

# %%
pd.options.display.max_columns = None
game_info.head(5)
# Out:
#     game_id            game_date  attendance game_time
# 0  24600001  1946-11-01 00:00:00         NaN       NaN
# 1  24600003  1946-11-02 00:00:00         NaN       NaN
# 2  24600002  1946-11-02 00:00:00         NaN       NaN
# 3  24600004  1946-11-02 00:00:00         NaN       NaN
# 4  24600005  1946-11-02 00:00:00         NaN       NaN

# %%
game_info['game_date'] = pd.to_datetime(game_info['game_date'])
game_info = game_info[game_info['game_date'] >= '01-01-2013']
game_info.isnull().sum()
# Out:
# game_id         0
# game_date       0
# attendance    799
# game_time     105
# dtype: int64

# %%
pd.options.display.max_columns = None
game_summary.head(5)
# Out:
#   game_date_est  game_sequence   game_id  game_status_id game_status_text  \
# 0    1946-11-01            NaN  24600001               3              NaN
# 1    1946-11-02            NaN  24600003               3              NaN
# 2    1946-11-02            NaN  24600002               3              NaN
# 3    1946-11-02            NaN  24600004               3              NaN
# 4    1946-11-02            NaN  24600005               3              NaN
#
#           gamecode  home_team_id  visitor_team_id  season  live_period  \
# 0  19461101/NYKHUS    1610610035       1610612752    1946            5
# 1  19461102/PITBOM    1610610034       1610610031    1946            4
# 2  19461102/BOSPRO    1610610032       1610612738    1946            4
# 3  19461102/NYKCHS    1610610025       1610612752    1946            4
# 4  19461102/WASDEF    1610610028       1610610036    1946            4
#
#   live_pc_time natl_tv_broadcaster_abbreviation live_period_time_bcast  \
# ...

# %%
game_summary['game_date_est'] = pd.to_datetime(game_summary['game_date_est'])
game_summary = game_summary[game_summary['game_date_est'] >= '01-01-2013']
game_summary.isnull().sum()
# Out:
# game_date_est                           0
# game_sequence                           0
# game_id                                 0
# game_status_id                          0
# game_status_text                        0
# gamecode                                0
# home_team_id                            0
# visitor_team_id                         0
# season                                  0
# live_period                             0
# live_pc_time                        10437
# natl_tv_broadcaster_abbreviation     8932
# live_period_time_bcast                  0
# wh_status                               0
# dtype: int64

# %%
game_summary.shape
# Out:
# (12459, 14)

# %%
game_summary
# Out:
#              game_date_est  game_sequence   game_id  game_status_id  \
# 0      1946-11-01 00:00:00            NaN  24600001               3
# 1      1946-11-02 00:00:00            NaN  24600003               3
# 2      1946-11-02 00:00:00            NaN  24600002               3
# 3      1946-11-02 00:00:00            NaN  24600004               3
# 4      1946-11-02 00:00:00            NaN  24600005               3
# ...                    ...            ...       ...             ...
# 58105  2023-06-07 00:00:00            1.0  42200403               3
# 58106  2023-06-09 00:00:00            1.0  42200404               3
# 58107  2023-06-12 00:00:00            1.0  42200405               3
# 58108  2023-02-19 00:00:00            1.0  32200001               3
# 58109  2023-02-19 00:00:00            1.0  32200001               3
#
#       game_status_text         gamecode  home_team_id  visitor_team_id  \
# 0                  NaN  19461101/NYKHUS    1610610035       1610612752
# ...

# %%
pd.options.display.max_columns = None
inactive_players.head(5)
# Out:
#     game_id  player_id first_name last_name  jersey_num     team_id  \
# 0  29600034        184      Bobby    Phills        14.0  1610612739
# 1  29600034        781       Will    Perdue        41.0  1610612759
# 2  29600132        120     Steven     Smith         8.0  1610612737
# 3  29600203        698      Eddie   Johnson         8.0  1610612754
# 4  29600213         32   Clifford    Rozier        44.0  1610612753
#
#      team_city  team_name team_abbreviation
# 0    Cleveland  Cavaliers               CLE
# 1  San Antonio      Spurs               SAS
# 2      Atlanta      Hawks               ATL
# 3      Indiana     Pacers               IND
# 4      Orlando      Magic               ORL

# %%
inactive_players.isnull().sum()
# Out:
# game_id               0
# player_id             0
# first_name            1
# last_name             1
# jersey_num           43
# team_id               0
# team_city             0
# team_name             0
# team_abbreviation     0
# dtype: int64

# %%
inactive_players.shape
# Out:
# (110191, 9)

# %%
pd.options.display.max_columns = None
line_score.head(5)
# Out:
#          game_date_est  game_sequence   game_id  team_id_home  \
# 0  1946-11-01 00:00:00            NaN  24600001    1610610035
# 1  1946-11-02 00:00:00            NaN  24600003    1610610034
# 2  1946-11-02 00:00:00            NaN  24600002    1610612738
# 3  1946-11-02 00:00:00            NaN  24600004    1610610025
# 4  1946-11-02 00:00:00            NaN  24600005    1610610036
#
#   team_abbreviation_home team_city_name_home team_nickname_home  \
# 0                    HUS             Toronto            Huskies
# 1                    BOM           St. Louis            Bombers
# 2                    BOS              Boston            Celtics
# 3                    CHS             Chicago              Stags
# 4                    WAS          Washington           Capitols
#
#   team_wins_losses_home  pts_qtr1_home  pts_qtr2_home  pts_qtr3_home  \
# 0                     -            NaN            NaN            NaN
# ...

# %%
line_score['game_date_est'] = pd.to_datetime(line_score['game_date_est'])
line_score = line_score[line_score['game_date_est'] >= '01-01-2013']
line_score.isnull().sum()
# Out:
# game_date_est             0
# game_sequence             0
# game_id                   0
# team_id_home              0
# team_abbreviation_home    0
# team_city_name_home       0
# team_nickname_home        0
# team_wins_losses_home     0
# pts_qtr1_home             0
# pts_qtr2_home             0
# pts_qtr3_home             0
# pts_qtr4_home             0
# pts_ot1_home              0
# pts_ot2_home              0
# pts_ot3_home              0
# pts_ot4_home              0
# pts_ot5_home              0
# pts_ot6_home              0
# pts_ot7_home              0
# pts_ot8_home              0
# pts_ot9_home              0
# pts_ot10_home             0
# pts_home                  0
# team_id_away              0
# team_abbreviation_away    0
# team_city_name_away       0
# team_nickname_away        0
# team_wins_losses_away     0
# pts_qtr1_away             0
# pts_qtr2_away             0
# pts_qtr3_away             0
# pts_qtr4_away             0
# pts_ot1_away              0
# ...

# %%
line_score.shape
# Out:
# (12410, 43)

# %%
line_score
# Out:
#       game_date_est  game_sequence   game_id  team_id_home  \
# 45643    2013-04-20            2.0  41200161    1610612744
# 45644    2013-04-20            3.0  41200131    1610612751
# 45645    2013-04-20            1.0  41200111    1610612752
# 45646    2013-04-20            4.0  41200171    1610612763
# 45647    2013-04-21            1.0  41200121    1610612754
# ...             ...            ...       ...           ...
# 58048    2023-06-07            1.0  42200403    1610612748
# 58049    2023-06-09            1.0  42200404    1610612748
# 58050    2023-06-12            1.0  42200405    1610612743
# 58051    2023-02-19            1.0  32200001    1610616834
# 58052    2023-02-19            1.0  32200001    1610616834
#
#       team_abbreviation_home team_city_name_home team_nickname_home  \
# 45643                    GSW        Golden State           Warriors
# 45644                    BKN            Brooklyn               Nets
# ...

# %%
pd.options.display.max_columns = None
officials.head(5)
# Out:
#     game_id  official_id first_name  last_name  jersey_num
# 0  29600059         1140      Bruce  Alexander         9.0
# 1  29600059         1165       Luis     Grillo         8.0
# 2  29600059         1153        Joe   Crawford        17.0
# 3  29600114         1147       Mike   Callahan        24.0
# 4  29600114         1142       Dick    Bavetta        27.0

# %%
pd.options.display.max_columns = None
other_stats.head(5)
# Out:
#     game_id  league_id  team_id_home team_abbreviation_home team_city_home  \
# 0  29600012          0    1610612756                    PHX        Phoenix
# 1  29600005          0    1610612737                    ATL        Atlanta
# 2  29600002          0    1610612739                    CLE      Cleveland
# 3  29600007          0    1610612754                    IND        Indiana
# 4  29600013          0    1610612746                    LAC    Los Angeles
#
#    pts_paint_home  pts_2nd_chance_home  pts_fb_home  largest_lead_home  \
# 0              44                   18            2                  1
# 1              32                    9            6                  0
# 2              36                   14            6                 20
# 3              34                   11            4                 10
# 4              40                   19            2                 12
#
#    lead_changes  times_tied  team_turnovers_home  total_turnovers_home  \
# ...

# %%
other_stats.shape
# Out:
# (28271, 26)

# %%
other_stats.isnull().sum()
# Out:
# game_id                      0
# league_id                    0
# team_id_home                 0
# team_abbreviation_home       0
# team_city_home               0
# pts_paint_home               0
# pts_2nd_chance_home          0
# pts_fb_home                  0
# largest_lead_home            0
# lead_changes                 0
# times_tied                   0
# team_turnovers_home          2
# total_turnovers_home       316
# team_rebounds_home        1998
# pts_off_to_home           2123
# team_id_away                 0
# team_abbreviation_away       0
# team_city_away               0
# pts_paint_away               0
# pts_2nd_chance_away          0
# pts_fb_away                  0
# largest_lead_away            0
# team_turnovers_away          2
# total_turnovers_away       316
# team_rebounds_away        1998
# pts_off_to_away           2123
# dtype: int64

# %%
pd.options.display.max_columns = None
player.head(5)
# Out:
#       id            full_name first_name     last_name  is_active
# 0  76001       Alaa Abdelnaby       Alaa     Abdelnaby          0
# 1  76002      Zaid Abdul-Aziz       Zaid    Abdul-Aziz          0
# 2  76003  Kareem Abdul-Jabbar     Kareem  Abdul-Jabbar          0
# 3     51   Mahmoud Abdul-Rauf    Mahmoud    Abdul-Rauf          0
# 4   1505    Tariq Abdul-Wahad      Tariq   Abdul-Wahad          0

# %%
player.isnull().sum()
# Out:
# id            0
# full_name     0
# first_name    6
# last_name     0
# is_active     0
# dtype: int64

# %%
pd.options.display.max_columns = None
play_by_play.head(5)
# Out:
#      game_id  eventnum  eventmsgtype  eventmsgactiontype  period wctimestring  \
# 0   29600012         0            12                   0       1     14:43 PM
# 1   29600012         2            10                   0       1     14:50 PM
# 2   29600012         3             2                   1       1     14:51 PM
# 3   29600012         4             4                   0       1     14:51 PM
# 4   29600012         5             2                   1       1     14:51 PM
# 5   29600012         6             4                   0       1     14:51 PM
# 6   29600012         7             6                   1       1     14:51 PM
# 7   29600012         8             5                   1       1     14:52 PM
# 8   29600012         9             2                   5       1     14:52 PM
# 9   29600012        10             4                   0       1     14:52 PM
# 10  29600012        11             5                   2       1     14:52 PM
# ...

# %%
play_by_play.shape
# Out:
# (13592899, 34)

# %%
play_by_play.isnull().sum()
# Out:
# game_id                             0
# eventnum                            0
# eventmsgtype                        0
# eventmsgactiontype                  0
# period                              0
# wctimestring                      950
# pctimestring                        0
# homedescription               6530241
# neutraldescription           13273327
# visitordescription            6634527
# score                        10028436
# scoremargin                  10028436
# person1type                      3298
# player1_id                          0
# player1_name                  1208875
# player1_team_id               1215858
# player1_team_city             1215858
# player1_team_nickname         1215858
# player1_team_abbreviation     1215858
# person2type                         0
# player2_id                          0
# player2_name                  9683745
# player2_team_id               9660454
# player2_team_city             9660454
# player2_team_nickname         9660454
# ...

# %%
pd.options.display.max_columns = None
team.head(5)
# Out:
#            id             full_name abbreviation   nickname         city  \
# 0  1610612737         Atlanta Hawks          ATL      Hawks      Atlanta
# 1  1610612738        Boston Celtics          BOS    Celtics       Boston
# 2  1610612739   Cleveland Cavaliers          CLE  Cavaliers    Cleveland
# 3  1610612740  New Orleans Pelicans          NOP   Pelicans  New Orleans
# 4  1610612741         Chicago Bulls          CHI      Bulls      Chicago
#
#            state  year_founded
# 0        Atlanta        1949.0
# 1  Massachusetts        1946.0
# 2           Ohio        1970.0
# 3      Louisiana        2002.0
# 4       Illinois        1966.0

# %%
team.isnull().sum()
# Out:
# id              0
# full_name       0
# abbreviation    0
# nickname        0
# city            0
# state           0
# year_founded    0
# dtype: int64

# %%
pd.options.display.max_columns = None
team_details.head(5)
# Out:
#       team_id abbreviation   nickname  yearfounded          city  \
# 0  1610612737          ATL      Hawks       1949.0       Atlanta
# 1  1610612741          CHI      Bulls       1966.0       Chicago
# 2  1610612742          DAL  Mavericks       1980.0        Dallas
# 3  1610612743          DEN    Nuggets       1976.0        Denver
# 4  1610612744          GSW   Warriors       1946.0  Golden State
#
#                       arena  arenacapacity              owner  \
# 0          State Farm Arena        18729.0       Tony Ressler
# 1             United Center        21711.0  Michael Reinsdorf
# 2  American Airlines Center        19200.0         Mark Cuban
# 3                Ball Arena            NaN       Stan Kroenke
# 4              Chase Center            NaN          Joe Lacob
#
#        generalmanager       headcoach     dleagueaffiliation  \
# 0      Travis Schlenk     Quin Snyder  College Park Skyhawks
# 1  Arturas Karnisovas   Billy Donovan       Windy City Bulls
# ...

# %%
pd.options.display.max_columns = None
team_history.head(5)
# Out:
#       team_id        city    nickname  year_founded  year_active_till
# 0  1610612737     Atlanta       Hawks          1968              2019
# 1  1610612737   St. Louis       Hawks          1955              1967
# 2  1610612737   Milwaukee       Hawks          1951              1954
# 3  1610612737  Tri-Cities  Blackhawks          1949              1950
# 4  1610612741     Chicago       Bulls          1966              2019

# %%
pd.options.display.max_columns = None
team_info_common.head(5)
# Out:
# Empty DataFrame
# Columns: [team_id, season_year, team_city, team_name, team_abbreviation, team_conference, team_division, team_code, team_slug, w, l, pct, conf_rank, div_rank, min_year, max_year, league_id, season_id, pts_rank, pts_pg, reb_rank, reb_pg, ast_rank, ast_pg, opp_pts_rank, opp_pts_pg]
# Index: []

# %%
common_player_info.shape
# Out:
# (4171, 33)

# %%
common_player_info.isnull().sum()
# Out:
# person_id                             0
# first_name                            0
# last_name                             0
# display_first_last                    0
# display_last_comma_first              0
# display_fi_last                       0
# player_slug                           0
# birthdate                             0
# school                               15
# country                               1
# last_affiliation                      0
# height                               96
# weight                              100
# season_exp                            0
# jersey                              980
# position                             63
# rosterstatus                          0
# games_played_current_season_flag      0
# team_id                               0
# team_name                           702
# team_abbreviation                   702
# team_code                           702
# team_city                           702
# ...

# %%
draft_combine_stats.shape
# Out:
# (1202, 47)

# %%
draft_combine_stats.isnull().sum()
# Out:
# season                             0
# player_id                          0
# first_name                         0
# last_name                          0
# player_name                        0
# position                           5
# height_wo_shoes                   49
# height_wo_shoes_ft_in             49
# height_w_shoes                   194
# height_w_shoes_ft_in             194
# weight                            50
# wingspan                          49
# wingspan_ft_in                    49
# standing_reach                    50
# standing_reach_ft_in              50
# body_fat_pct                     199
# hand_length                      483
# hand_width                       483
# standing_vertical_leap           185
# max_vertical_leap                185
# lane_agility_time                194
# modified_lane_agility_time       791
# three_quarter_sprint             190
# bench_press                      394
# spot_fifteen_corner_left        1128
# ...

# %%
draft_history.shape
# Out:
# (7990, 14)

# %%
draft_history.isnull().sum()
# Out:
# person_id               0
# player_name             0
# season                  0
# round_number            0
# round_pick              0
# overall_pick            0
# draft_type              0
# team_id                 0
# team_city               0
# team_name               0
# team_abbreviation       0
# organization           19
# organization_type      19
# player_profile_flag     0
# dtype: int64

# %%
game.shape
# Out:
# (65698, 55)

# %%
game.isnull().sum()
# Out:
# season_id                     0
# team_id_home                  0
# team_abbreviation_home        0
# team_name_home                0
# game_id                       0
# game_date                     0
# matchup_home                  0
# wl_home                       2
# min                           0
# fgm_home                     13
# fga_home                  15447
# fg_pct_home               15490
# fg3m_home                 13218
# fg3a_home                 18683
# fg3_pct_home              19074
# ftm_home                     16
# fta_home                   3004
# ft_pct_home                3009
# oreb_home                 18936
# dreb_home                 18999
# reb_home                  15729
# ast_home                  15805
# stl_home                  18849
# blk_home                  18626
# tov_home                  18684
# pf_home                    2856
# pts_home                      0
# plus_minus_home               0
# video_available_home          0
# ...

# %%
game_info.shape
# Out:
# (58053, 4)

# %%
game_info.isnull().sum()
# Out:
# game_id           0
# game_date         0
# attendance     5380
# game_time     28111
# dtype: int64

# %%
game_summary.shape
# Out:
# (58110, 14)

# %%
game_summary.isnull().sum()
# Out:
# game_date_est                           0
# game_sequence                       25532
# game_id                                 0
# game_status_id                          0
# game_status_text                    25986
# gamecode                                0
# home_team_id                            0
# visitor_team_id                         0
# season                                  0
# live_period                             0
# live_pc_time                        56086
# natl_tv_broadcaster_abbreviation    51907
# live_period_time_bcast                  0
# wh_status                               0
# dtype: int64

# %%
inactive_players.shape
# Out:
# (110191, 9)

# %%
inactive_players.isnull().sum()
# Out:
# game_id               0
# player_id             0
# first_name            1
# last_name             1
# jersey_num           43
# team_id               0
# team_city             0
# team_name             0
# team_abbreviation     0
# dtype: int64

# %%
line_score.shape
# Out:
# (58053, 43)

# %%
line_score.isnull().sum()
# Out:
# game_date_est                 0
# game_sequence             25532
# game_id                       0
# team_id_home                  0
# team_abbreviation_home        0
# team_city_name_home           0
# team_nickname_home            0
# team_wins_losses_home         0
# pts_qtr1_home              1004
# pts_qtr2_home              1013
# pts_qtr3_home              1045
# pts_qtr4_home              1044
# pts_ot1_home              25759
# pts_ot2_home              27051
# pts_ot3_home              27243
# pts_ot4_home              27270
# pts_ot5_home              45577
# pts_ot6_home              45578
# pts_ot7_home              45578
# pts_ot8_home              45578
# pts_ot9_home              45578
# pts_ot10_home             45578
# pts_home                      0
# team_id_away                  0
# team_abbreviation_away        0
# team_city_name_away           0
# team_nickname_away            0
# team_wins_losses_away         0
# pts_qtr1_away              1010
# ...

# %%
officials.shape
# Out:
# (70971, 5)

# %%
officials.isnull().sum()
# Out:
# game_id          0
# official_id      0
# first_name       0
# last_name        0
# jersey_num     190
# dtype: int64

# %%
other_stats.shape
# Out:
# (28271, 26)

# %%
other_stats.isnull().sum()
# Out:
# game_id                      0
# league_id                    0
# team_id_home                 0
# team_abbreviation_home       0
# team_city_home               0
# pts_paint_home               0
# pts_2nd_chance_home          0
# pts_fb_home                  0
# largest_lead_home            0
# lead_changes                 0
# times_tied                   0
# team_turnovers_home          2
# total_turnovers_home       316
# team_rebounds_home        1998
# pts_off_to_home           2123
# team_id_away                 0
# team_abbreviation_away       0
# team_city_away               0
# pts_paint_away               0
# pts_2nd_chance_away          0
# pts_fb_away                  0
# largest_lead_away            0
# team_turnovers_away          2
# total_turnovers_away       316
# team_rebounds_away        1998
# pts_off_to_away           2123
# dtype: int64

# %%
player.shape
# Out:
# (4831, 5)

# %%
player.isnull().sum()
# Out:
# id            0
# full_name     0
# first_name    6
# last_name     0
# is_active     0
# dtype: int64

# %%
play_by_play.shape
# Out:
# (13592899, 34)

# %%
play_by_play.isnull().sum()
# Out:
# game_id                             0
# eventnum                            0
# eventmsgtype                        0
# eventmsgactiontype                  0
# period                              0
# wctimestring                      950
# pctimestring                        0
# homedescription               6530241
# neutraldescription           13273327
# visitordescription            6634527
# score                        10028436
# scoremargin                  10028436
# person1type                      3298
# player1_id                          0
# player1_name                  1208875
# player1_team_id               1215858
# player1_team_city             1215858
# player1_team_nickname         1215858
# player1_team_abbreviation     1215858
# person2type                         0
# player2_id                          0
# player2_name                  9683745
# player2_team_id               9660454
# player2_team_city             9660454
# player2_team_nickname         9660454
# ...

# %%
team.shape
# Out:
# (30, 7)

# %%
team.isnull().sum()
# Out:
# id              0
# full_name       0
# abbreviation    0
# nickname        0
# city            0
# state           0
# year_founded    0
# dtype: int64

# %%
team_details.shape
# Out:
# (25, 14)

# %%
team_details.isnull().sum()
# Out:
# team_id               0
# abbreviation          0
# nickname              0
# yearfounded           0
# city                  0
# arena                 0
# arenacapacity         9
# owner                 0
# generalmanager        0
# headcoach             1
# dleagueaffiliation    0
# facebook              0
# instagram             0
# twitter               0
# dtype: int64

# %%
team_history.shape
# Out:
# (52, 5)

# %%
team_history.isnull().sum()
# Out:
# team_id             0
# city                0
# nickname            0
# year_founded        0
# year_active_till    0
# dtype: int64

# %%
team_info_common.shape
# Out:
# (0, 26)

# %%
team_info_common.isnull().sum()
# Out:
# team_id              0
# season_year          0
# team_city            0
# team_name            0
# team_abbreviation    0
# team_conference      0
# team_division        0
# team_code            0
# team_slug            0
# w                    0
# l                    0
# pct                  0
# conf_rank            0
# div_rank             0
# min_year             0
# max_year             0
# league_id            0
# season_id            0
# pts_rank             0
# pts_pg               0
# reb_rank             0
# reb_pg               0
# ast_rank             0
# ast_pg               0
# opp_pts_rank         0
# opp_pts_pg           0
# dtype: int64
